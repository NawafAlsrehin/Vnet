# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Activation, Dropout, Flatten, Dense
import os
import cv2
from PIL import Image
import numpy as np
import glob

img_path = "/content/drive/MyDrive/ColabData/Database/statefarm/"
#'C:/Users/User/OneDrive - UW-Madison/WISC/Dataset/Egypt-auc.distracted.driver.dataset_v2/v2_cam1_cam2_ split_by_driver/Camera 1/train/'

counter_folders = 0
total_images = 0
for directory_path in glob.glob('/content/drive/MyDrive/ColabData/Database/statefarm/*'):
    label = directory_path.split("/")[-1]
    counter_images = 0
    for img_path in glob.glob(os.path.join(directory_path , "*.*")):
        #print(img_path)
        counter_images +=1
    print("For label: ", label, ", counter_images = ", counter_images)
    counter_folders += 1
    total_images +=counter_images
print("Total Folders = ", counter_folders)
print("Total Images = ", total_images)
# Out:
# For label:  c0 , counter_images =  2489
# For label:  c1 , counter_images =  2267
# For label:  c2 , counter_images =  2180
# For label:  c3 , counter_images =  2346
# For label:  c4 , counter_images =  2326
# For label:  c5 , counter_images =  2312
# For label:  c6 , counter_images =  2325
# For label:  c7 , counter_images =  2002
# For label:  c8 , counter_images =  1911
# For label:  c9 , counter_images =  2180
# For label:  prediction_state_9955_accurecy.xlsx , counter_images =  0
# For label:  prediction_state_9917_accurecy.xlsx , counter_images =  0
# For label:  model_mult_class_classification_unet_9955_accurecy.h5 , counter_images =  0
# For label:  prediction_state_99_accurecy_e2_updated.xlsx , counter_images =  0
# For label:  training_updated.xlsx , counter_images =  0
# For label:  prediction_state_99_accurecy_e2.xlsx , counter_images =  0
# For label:  training.xlsx , counter_images =  0
# Total Folders =  17
# Total Images =  22338

# %%
image_directory = "/content/drive/MyDrive/ColabData/Database/statefarm/"
            
SIZE = 256
dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
label = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected
save_images = os.listdir(image_directory + 'c0/')
for i, image_name in enumerate(save_images):    #Remember enumerate method adds a counter and returns the enumerate object
    
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c0/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(0)

#Iterate through all images in Uninfected folder, resize to 64 x 64
#Then save into the same numpy array 'dataset' but with label 1

mobile_images = os.listdir(image_directory + 'c1/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c1/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(1)

mobile_images = os.listdir(image_directory + 'c2/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c2/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(2)

mobile_images = os.listdir(image_directory + 'c3/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c3/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(3)

mobile_images = os.listdir(image_directory + 'c4/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c4/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(4)

mobile_images = os.listdir(image_directory + 'c5/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c5/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(5)

mobile_images = os.listdir(image_directory + 'c6/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c6/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(6)

mobile_images = os.listdir(image_directory + 'c7/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c7/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(7)

mobile_images = os.listdir(image_directory + 'c8/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c8/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(8)

mobile_images = os.listdir(image_directory + 'c9/')
for i, image_name in enumerate(mobile_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'c9/' + image_name)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(9)
        
dataset = np.array(dataset)
label = np.array(label)
print(dataset.shape)
print(label.shape)
# Out:
# (22287, 256, 256, 3)
# (22287,)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.utils import normalize, to_categorical
from keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(dataset, label, test_size = 0.2, random_state = 0)

print("The size of training dataset x is: ", X_train.shape)
print("The size of testing dataset x is: ", X_test.shape)
print("The size of training dataset y is: ", y_train.shape)
print("The size of testing dataset y is: ", y_test.shape)

#X_train = (X_train.astype('float32')) / 255.
#X_test = (X_test.astype('float32')) / 255.

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
# Out:
# The size of training dataset x is:  (17829, 256, 256, 3)
# The size of testing dataset x is:  (4458, 256, 256, 3)
# The size of training dataset y is:  (17829,)
# The size of testing dataset y is:  (4458,)

# %%
IMG_WIDTH = 256 #dataset.shape()[1] #128
IMG_HEIGHT = 256 # dataset.shape()[2] #128
IMG_CHANNELS = 3 # dataset.shape()[3] #3

print(IMG_WIDTH)
print(IMG_HEIGHT)
print(IMG_CHANNELS)

#Build the model
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#dirst Con layer
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s) # 256
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='same')(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1) # 128
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2, padding='same')(c2)


c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2) #64
c3 = tf.keras.layers.Dropout(0.1)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2, padding='same')(c3)

 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3) #32
c4 = tf.keras.layers.Dropout(0.1)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2, padding='same')(c4)


c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4) #16
c5 = tf.keras.layers.Dropout(0.1)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
p5 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2, padding='same')(c5)


c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p5) #8
c6 = tf.keras.layers.Dropout(0.1)(c6)
c6 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
p6 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2, padding='same')(c6)

c7 = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p6) #4
c7 = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

#Decode and concatenate path 
u8 = tf.keras.layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c7) # 8
u8 = tf.keras.layers.concatenate([u8, c6])
c8 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)


u9 = tf.keras.layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c8) # 16
u9 = tf.keras.layers.concatenate([u9, c5])
c9 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

 
u10 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c9) #32
u10 = tf.keras.layers.concatenate([u10, c4])
c10 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u10)
c10 = tf.keras.layers.Dropout(0.1)(c10)
c10 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)
 

u11 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c10) #64
u11 = tf.keras.layers.concatenate([u11, c3], axis=3)
c11 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u11)
c11 = tf.keras.layers.Dropout(0.1)(c11)
c11 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)


u12 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c11) #128
u12 = tf.keras.layers.concatenate([u12, c2], axis=3)
c12 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u12)
c12 = tf.keras.layers.Dropout(0.1)(c12)
c12 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c12)
 

u13 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c12) #256
u13 = tf.keras.layers.concatenate([u13, c1], axis=3)
c13 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u13)
c13 = tf.keras.layers.Dropout(0.1)(c13)
c13 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c13)
 
outputs = tf.keras.layers.Conv2D(10, (1, 1), activation='softmax')(c13) #256

#final layer for output
flat = Flatten()(c13)
out = Dense(10, activation='softmax')(flat) #1*10
 
model = tf.keras.Model(inputs=[inputs], outputs=[out]) #puts])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# 256
# 256
# 3
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['lambda[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
# ...

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns

filepath= img_path + 'unet_model-{epoch:02d}-{val_accuracy:.2f}.hdf5' #File name includes epoch and validation accuracy.
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
log_csv = CSVLogger(img_path + 'my_logs-{epoch:02d}-{val_accuracy:.2f}.csv', separator=',', append=False)

callbacks_list = [checkpoint, early_stop, log_csv]

history = model.fit(X_train, y_train_cat, 
                    batch_size = 64, 
                    verbose=1, 
                    epochs=50, 
                    validation_split=0.2,
                    validation_data=(X_test, y_test_cat), callbacks=callbacks_list)

# Save the model
model.save("/content/drive/MyDrive/ColabData/Database/statefarm/v_net_state_farm_99_55_accuracy.h5")

# Drwa the loss and accuracy curves 
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Testing loss')
plt.title('Training and Testing loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Testing acc')
plt.title('Training and testing accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 279/279 [==============================] - ETA: 0s - loss: 3.0856 - accuracy: 0.6464
# Epoch 1: val_accuracy improved from -inf to 0.96209, saving model to /content/drive/MyDrive/ColabData/Database/statefarm/c9/img_16668.jpgunet_model-01-0.96.hdf5
# 279/279 [==============================] - 230s 754ms/step - loss: 3.0856 - accuracy: 0.6464 - val_loss: 0.1413 - val_accuracy: 0.9621
# Epoch 2/50
# 279/279 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9860
# Epoch 2: val_accuracy improved from 0.96209 to 0.98677, saving model to /content/drive/MyDrive/ColabData/Database/statefarm/c9/img_16668.jpgunet_model-02-0.99.hdf5
# 279/279 [==============================] - 202s 724ms/step - loss: 0.0486 - accuracy: 0.9860 - val_loss: 0.0574 - val_accuracy: 0.9868
# Epoch 3/50
# 279/279 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9975
# Epoch 3: val_accuracy did not improve from 0.98677
# ...

# %%
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, recall_score, precision_score, f1_score
import pandas as pd
import numpy as np
import pandas as pd

# Evaluation the Testing data in terms of accuracy, error, and confusion matrix
# we used the confusion matrix to calculate the recall, precision, IoU, and F-score

prediction_test_unet = model.predict(X_test)

error, acc = model.evaluate(X_test, y_test_cat)
print("Testing Accuracy = ", (acc * 100.0), "%")
print("Testing Error = ", (error))

y_test_cat_df = pd.DataFrame(y_test_cat)
prediction_test_unit_df = pd.DataFrame(prediction_test_unet)

with pd.ExcelWriter('/content/drive/MyDrive/ColabData/Database/statefarm/vnet_testing_results.xlsx') as writer:
  y_test_cat_df.to_excel(writer, sheet_name='truth_values')
  prediction_test_unit_df.to_excel(writer, sheet_name='prediction')

# Evaluation the Training data in terms of accuracy, error, and confusion matrix
# we used the confusion matrix to calculate the recall, precision, IoU, and F-score

prediction_train_unet = model.predict(X_train)

error, acc = model.evaluate(X_train, y_train_cat)
print("Training Accuracy = ", (acc * 100.0), "%")
print("Training Error = ", (error))

y_train_cat_df = pd.DataFrame(y_train_cat)
prediction_train_df = pd.DataFrame(prediction_train_unet)

with pd.ExcelWriter('/content/drive/MyDrive/ColabData/Database/statefarm/vnet_training.xlsx') as writer:
  y_train_cat_df.to_excel(writer, sheet_name='truth_values')
  prediction_train_df.to_excel(writer, sheet_name='prediction')
# Out:
# ...
# 140/140 [==============================] - 15s 105ms/step - loss: 0.0357 - accuracy: 0.9948
# Testing Accuracy =  99.48407411575317 %
# Testing Error =  0.035708580166101456
# ...
# 558/558 [==============================] - 58s 104ms/step - loss: 1.5073e-05 - accuracy: 1.0000
# Training Accuracy =  100.0 %
# Training Error =  1.5072921087266877e-05

# %%
# process the excel sheet  by deleting the first row and colomun, and change the notation to one-hot value.
# Reading processed testing sheet

df_truth_trained = pd.read_excel('/content/drive/MyDrive/ColabData/Database/statefarm/vnet_training_results_updated.xlsx', sheet_name='truth_values')
df_predicted_trained = pd.read_excel('/content/drive/MyDrive/ColabData/Database/statefarm/vnet_training_results_updated.xlsx', sheet_name='prediction_processed')
truth_training = df_truth_trained.to_numpy()
pred_training = df_predicted_trained.to_numpy()

# calculate the confusion matrix and show the heat map

cm_train = confusion_matrix(truth_training.argmax(axis=1), pred_training.argmax(axis=1))
x_axis_labels = ["c0","c1","c2", "c3", "c4","c5", "c6", "c7", "c8", "c9"] # labels for x-axis
y_axis_labels = ["c0","c1","c2", "c3", "c4","c5", "c6", "c7", "c8", "c9"] # labels for y-axis
sns.heatmap(cm_train, annot=True, fmt="d",cmap='Blues', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

# %%
# Reading processed testing sheet
df_truth_test = pd.read_excel('/content/drive/MyDrive/ColabData/Database/statefarm/vnet_testing_results_updated.xlsx', sheet_name='truth_values')
df_predicted_test = pd.read_excel('/content/drive/MyDrive/ColabData/Database/statefarm/vnet_testing_results_updated.xlsx', sheet_name='prediction_processed')
truth_test = df_truth_test.to_numpy()
pred_test = df_predicted_test.to_numpy()

# calculate the confusion matrix and show the heat map
cm_test = confusion_matrix(truth_test.argmax(axis=1), pred_test.argmax(axis=1))
sns.heatmap(cm_test, annot=True, fmt="d",cmap='Blues', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

# %%
# class-wise intersection over union - testing data
twoD_cm = cm_test

class0_IoU = twoD_cm[0,0]/(twoD_cm[0,0] + twoD_cm[0,1] + twoD_cm[0,2] + twoD_cm[0,3] + twoD_cm[0,4] + twoD_cm[0,5] + twoD_cm[0,6] + twoD_cm[0,7] + twoD_cm[0,8] + twoD_cm[0,9] + twoD_cm[1,0]+ twoD_cm[2,0]+ twoD_cm[3,0] + twoD_cm[4,0] + twoD_cm[5,0] + twoD_cm[6,0] + twoD_cm[7,0] + twoD_cm[8,0] + twoD_cm[9,0])
class1_IoU = twoD_cm[1,1]/(twoD_cm[1,0] + twoD_cm[1,1] + twoD_cm[1,2] + twoD_cm[1,3] + twoD_cm[1,4] + twoD_cm[1,5] + twoD_cm[1,6] + twoD_cm[1,7] + twoD_cm[1,8] + twoD_cm[1,9] + twoD_cm[0,1]+ twoD_cm[2,1]+ twoD_cm[3,1] + twoD_cm[4,1] + twoD_cm[5,1] + twoD_cm[6,1] + twoD_cm[7,1] + twoD_cm[8,1] + twoD_cm[9,1])
class2_IoU = twoD_cm[2,2]/(twoD_cm[2,0] + twoD_cm[2,1] + twoD_cm[2,2] + twoD_cm[2,3] + twoD_cm[2,4] + twoD_cm[2,5] + twoD_cm[2,6] + twoD_cm[2,7] + twoD_cm[2,8] + twoD_cm[2,9] + twoD_cm[0,2]+ twoD_cm[1,2]+ twoD_cm[3,2] + twoD_cm[4,2] + twoD_cm[5,2] + twoD_cm[6,2] + twoD_cm[7,2] + twoD_cm[8,2] + twoD_cm[9,2])
class3_IoU = twoD_cm[3,3]/(twoD_cm[3,0] + twoD_cm[3,1] + twoD_cm[3,2] + twoD_cm[3,3] + twoD_cm[3,4] + twoD_cm[3,5] + twoD_cm[3,6] + twoD_cm[3,7] + twoD_cm[3,8] + twoD_cm[3,9] + twoD_cm[0,3]+ twoD_cm[1,3]+ twoD_cm[2,3] + twoD_cm[4,3] + twoD_cm[5,3] + twoD_cm[6,3] + twoD_cm[7,3] + twoD_cm[8,3] + twoD_cm[9,3])
class4_IoU = twoD_cm[4,4]/(twoD_cm[4,0] + twoD_cm[4,1] + twoD_cm[4,2] + twoD_cm[4,3] + twoD_cm[4,4] + twoD_cm[4,5] + twoD_cm[4,6] + twoD_cm[4,7] + twoD_cm[4,8] + twoD_cm[4,9] + twoD_cm[0,4]+ twoD_cm[1,4]+ twoD_cm[2,4] + twoD_cm[3,4] + twoD_cm[5,4] + twoD_cm[6,4] + twoD_cm[7,4] + twoD_cm[8,4] + twoD_cm[9,4])
class5_IoU = twoD_cm[5,5]/(twoD_cm[5,0] + twoD_cm[5,1] + twoD_cm[5,2] + twoD_cm[5,3] + twoD_cm[5,4] + twoD_cm[5,5] + twoD_cm[5,6] + twoD_cm[5,7] + twoD_cm[5,8] + twoD_cm[5,9] + twoD_cm[0,5]+ twoD_cm[1,5]+ twoD_cm[2,5] + twoD_cm[3,5] + twoD_cm[4,5] + twoD_cm[6,5] + twoD_cm[7,5] + twoD_cm[8,5] + twoD_cm[9,5])
class6_IoU = twoD_cm[6,6]/(twoD_cm[6,0] + twoD_cm[6,1] + twoD_cm[6,2] + twoD_cm[6,3] + twoD_cm[6,4] + twoD_cm[6,5] + twoD_cm[6,6] + twoD_cm[6,7] + twoD_cm[6,8] + twoD_cm[6,9] + twoD_cm[0,6]+ twoD_cm[1,6]+ twoD_cm[2,6]+ twoD_cm[3,6] + twoD_cm[4,6] + twoD_cm[5,6] + twoD_cm[7,6] + twoD_cm[8,6] + twoD_cm[9,6])
class7_IoU = twoD_cm[7,7]/(twoD_cm[7,0] + twoD_cm[7,1] + twoD_cm[7,2] + twoD_cm[7,3] + twoD_cm[7,4] + twoD_cm[7,5] + twoD_cm[7,6] + twoD_cm[7,7] + twoD_cm[7,8] + twoD_cm[7,9] + twoD_cm[0,7]+ twoD_cm[1,7]+ twoD_cm[2,7]+ twoD_cm[3,7] + twoD_cm[4,7] + twoD_cm[5,7] + twoD_cm[6,7] + twoD_cm[8,7] + twoD_cm[9,7])
class8_IoU = twoD_cm[8,8]/(twoD_cm[8,0] + twoD_cm[8,1] + twoD_cm[8,2] + twoD_cm[8,3] + twoD_cm[8,4] + twoD_cm[8,5] + twoD_cm[8,6] + twoD_cm[8,7] + twoD_cm[8,8] + twoD_cm[8,9] + twoD_cm[0,8]+ twoD_cm[1,8]+ twoD_cm[2,8]+ twoD_cm[3,8] + twoD_cm[4,8] + twoD_cm[5,8] + twoD_cm[6,8] + twoD_cm[7,8]  + twoD_cm[9,8])
class9_IoU= twoD_cm[9,9]/(twoD_cm[9,0] + twoD_cm[9,1] + twoD_cm[9,2] + twoD_cm[9,3] + twoD_cm[9,4] + twoD_cm[9,5] + twoD_cm[9,6] + twoD_cm[9,7] + twoD_cm[9,8] + twoD_cm[9,9] + twoD_cm[0,9]+ twoD_cm[1,9]+ twoD_cm[2,9]+ twoD_cm[3,9] + twoD_cm[4,9] + twoD_cm[5,9] + twoD_cm[6,9] + twoD_cm[7,9] + twoD_cm[8,9] )


print("Test - IoU for class 0 is: ", "{:.2f}".format(class0_IoU *100), '%')
print("Test - IoU for class 1 is: ", "{:.2f}".format(class1_IoU *100), '%')
print("Test - IoU for class 2 is: ", "{:.2f}".format(class2_IoU *100), '%')
print("Test - IoU for class 3 is: ", "{:.2f}".format(class3_IoU *100), '%')
print("Test - IoU for class 4 is: ", "{:.2f}".format(class4_IoU *100), '%')
print("Test - IoU for class 5 is: ", "{:.2f}".format(class5_IoU *100), '%')
print("Test - IoU for class 6 is: ", "{:.2f}".format(class6_IoU *100), '%')
print("Test - IoU for class 7 is: ", "{:.2f}".format(class7_IoU *100), '%')
print("Test - IoU for class 8 is: ", "{:.2f}".format(class8_IoU *100), '%')
print("Test - IoU for class 9 is: ", "{:.2f}".format(class9_IoU *100), '%')
# Out:
# Test - IoU for class 0 is:  98.34 %
# Test - IoU for class 1 is:  99.76 %
# Test - IoU for class 2 is:  99.16 %
# Test - IoU for class 3 is:  99.38 %
# Test - IoU for class 4 is:  99.09 %
# Test - IoU for class 5 is:  99.36 %
# Test - IoU for class 6 is:  99.36 %
# Test - IoU for class 7 is:  99.24 %
# Test - IoU for class 8 is:  97.91 %
# Test - IoU for class 9 is:  98.06 %

# %%
# class-wise intersection over union - training data
twoD_cm = cm_train

class0_IoU = twoD_cm[0,0]/(twoD_cm[0,0] + twoD_cm[0,1] + twoD_cm[0,2] + twoD_cm[0,3] + twoD_cm[0,4] + twoD_cm[0,5] + twoD_cm[0,6] + twoD_cm[0,7] + twoD_cm[0,8] + twoD_cm[0,9] + twoD_cm[1,0]+ twoD_cm[2,0]+ twoD_cm[3,0] + twoD_cm[4,0] + twoD_cm[5,0] + twoD_cm[6,0] + twoD_cm[7,0] + twoD_cm[8,0] + twoD_cm[9,0])
class1_IoU = twoD_cm[1,1]/(twoD_cm[1,0] + twoD_cm[1,1] + twoD_cm[1,2] + twoD_cm[1,3] + twoD_cm[1,4] + twoD_cm[1,5] + twoD_cm[1,6] + twoD_cm[1,7] + twoD_cm[1,8] + twoD_cm[1,9] + twoD_cm[0,1]+ twoD_cm[2,1]+ twoD_cm[3,1] + twoD_cm[4,1] + twoD_cm[5,1] + twoD_cm[6,1] + twoD_cm[7,1] + twoD_cm[8,1] + twoD_cm[9,1])
class2_IoU = twoD_cm[2,2]/(twoD_cm[2,0] + twoD_cm[2,1] + twoD_cm[2,2] + twoD_cm[2,3] + twoD_cm[2,4] + twoD_cm[2,5] + twoD_cm[2,6] + twoD_cm[2,7] + twoD_cm[2,8] + twoD_cm[2,9] + twoD_cm[0,2]+ twoD_cm[1,2]+ twoD_cm[3,2] + twoD_cm[4,2] + twoD_cm[5,2] + twoD_cm[6,2] + twoD_cm[7,2] + twoD_cm[8,2] + twoD_cm[9,2])
class3_IoU = twoD_cm[3,3]/(twoD_cm[3,0] + twoD_cm[3,1] + twoD_cm[3,2] + twoD_cm[3,3] + twoD_cm[3,4] + twoD_cm[3,5] + twoD_cm[3,6] + twoD_cm[3,7] + twoD_cm[3,8] + twoD_cm[3,9] + twoD_cm[0,3]+ twoD_cm[1,3]+ twoD_cm[2,3] + twoD_cm[4,3] + twoD_cm[5,3] + twoD_cm[6,3] + twoD_cm[7,3] + twoD_cm[8,3] + twoD_cm[9,3])
class4_IoU = twoD_cm[4,4]/(twoD_cm[4,0] + twoD_cm[4,1] + twoD_cm[4,2] + twoD_cm[4,3] + twoD_cm[4,4] + twoD_cm[4,5] + twoD_cm[4,6] + twoD_cm[4,7] + twoD_cm[4,8] + twoD_cm[4,9] + twoD_cm[0,4]+ twoD_cm[1,4]+ twoD_cm[2,4] + twoD_cm[3,4] + twoD_cm[5,4] + twoD_cm[6,4] + twoD_cm[7,4] + twoD_cm[8,4] + twoD_cm[9,4])
class5_IoU = twoD_cm[5,5]/(twoD_cm[5,0] + twoD_cm[5,1] + twoD_cm[5,2] + twoD_cm[5,3] + twoD_cm[5,4] + twoD_cm[5,5] + twoD_cm[5,6] + twoD_cm[5,7] + twoD_cm[5,8] + twoD_cm[5,9] + twoD_cm[0,5]+ twoD_cm[1,5]+ twoD_cm[2,5] + twoD_cm[3,5] + twoD_cm[4,5] + twoD_cm[6,5] + twoD_cm[7,5] + twoD_cm[8,5] + twoD_cm[9,5])
class6_IoU = twoD_cm[6,6]/(twoD_cm[6,0] + twoD_cm[6,1] + twoD_cm[6,2] + twoD_cm[6,3] + twoD_cm[6,4] + twoD_cm[6,5] + twoD_cm[6,6] + twoD_cm[6,7] + twoD_cm[6,8] + twoD_cm[6,9] + twoD_cm[0,6]+ twoD_cm[1,6]+ twoD_cm[2,6]+ twoD_cm[3,6] + twoD_cm[4,6] + twoD_cm[5,6] + twoD_cm[7,6] + twoD_cm[8,6] + twoD_cm[9,6])
class7_IoU = twoD_cm[7,7]/(twoD_cm[7,0] + twoD_cm[7,1] + twoD_cm[7,2] + twoD_cm[7,3] + twoD_cm[7,4] + twoD_cm[7,5] + twoD_cm[7,6] + twoD_cm[7,7] + twoD_cm[7,8] + twoD_cm[7,9] + twoD_cm[0,7]+ twoD_cm[1,7]+ twoD_cm[2,7]+ twoD_cm[3,7] + twoD_cm[4,7] + twoD_cm[5,7] + twoD_cm[6,7] + twoD_cm[8,7] + twoD_cm[9,7])
class8_IoU = twoD_cm[8,8]/(twoD_cm[8,0] + twoD_cm[8,1] + twoD_cm[8,2] + twoD_cm[8,3] + twoD_cm[8,4] + twoD_cm[8,5] + twoD_cm[8,6] + twoD_cm[8,7] + twoD_cm[8,8] + twoD_cm[8,9] + twoD_cm[0,8]+ twoD_cm[1,8]+ twoD_cm[2,8]+ twoD_cm[3,8] + twoD_cm[4,8] + twoD_cm[5,8] + twoD_cm[6,8] + twoD_cm[7,8]  + twoD_cm[9,8])
class9_IoU= twoD_cm[9,9]/(twoD_cm[9,0] + twoD_cm[9,1] + twoD_cm[9,2] + twoD_cm[9,3] + twoD_cm[9,4] + twoD_cm[9,5] + twoD_cm[9,6] + twoD_cm[9,7] + twoD_cm[9,8] + twoD_cm[9,9] + twoD_cm[0,9]+ twoD_cm[1,9]+ twoD_cm[2,9]+ twoD_cm[3,9] + twoD_cm[4,9] + twoD_cm[5,9] + twoD_cm[6,9] + twoD_cm[7,9] + twoD_cm[8,9] )


print("Train - IoU for class 0 is: ", "{:.2f}".format(class0_IoU *100), '%')
print("Train - IoU for class 1 is: ", "{:.2f}".format(class1_IoU *100), '%')
print("Train - IoU for class 2 is: ", "{:.2f}".format(class2_IoU *100), '%')
print("Train - IoU for class 3 is: ", "{:.2f}".format(class3_IoU *100), '%')
print("Train - IoU for class 4 is: ", "{:.2f}".format(class4_IoU *100), '%')
print("Train - IoU for class 5 is: ", "{:.2f}".format(class5_IoU *100), '%')
print("Train - IoU for class 6 is: ", "{:.2f}".format(class6_IoU *100), '%')
print("Train - IoU for class 7 is: ", "{:.2f}".format(class7_IoU *100), '%')
print("Train - IoU for class 8 is: ", "{:.2f}".format(class8_IoU *100), '%')
print("Train - IoU for class 9 is: ", "{:.2f}".format(class9_IoU *100), '%')

#===========================================
#This section calculates the recall and precision using the confusion matrix
#https://stackoverflow.com/questions/40729875/calculate-precision-and-recall-in-a-confusion-matrix
#https://www.analyticsvidhya.com/blog/2021/06/confusion-matrix-for-multi-class-classification/
from operator import truediv
tp_test = np.diag(cm_test)
prec_test = list(map(truediv, tp_test, np.sum(cm_test, axis=0)))
rec_test = list(map(truediv, tp_test, np.sum(cm_test, axis=1)))
print ('Testing: Precision: {}\nRecall: {}'.format(prec_test, rec_test))
#============================================
tp_train = np.diag(cm_test)
prec_train = list(map(truediv, tp_train, np.sum(cm_test, axis=0)))
rec_train = list(map(truediv, tp_train, np.sum(cm_test, axis=1)))
print ('Training: Precision: {}\nRecall: {}'.format(prec_train, rec_train))
#============================================
# This section calculates the accurecy and IoU

accuracy_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]
accuracy__test_all = accuracy_test.diagonal()
print('Testing: Accuracy = ', accuracy__test_all)

accuracy_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
accuracy__train_all = accuracy_train.diagonal()
print('Training: Accuracy = ', accuracy__train_all)
# Out:
# Train - IoU for class 0 is:  100.00 %
# Train - IoU for class 1 is:  100.00 %
# Train - IoU for class 2 is:  100.00 %
# Train - IoU for class 3 is:  100.00 %
# Train - IoU for class 4 is:  100.00 %
# Train - IoU for class 5 is:  100.00 %
# Train - IoU for class 6 is:  100.00 %
# Train - IoU for class 7 is:  100.00 %
# Train - IoU for class 8 is:  100.00 %
# Train - IoU for class 9 is:  100.00 %
# Testing: Precision: [0.9852125693160814, 0.9975728155339806, 0.9957805907172996, 0.9958246346555324, 0.9954233409610984, 0.9957537154989384, 1.0, 1.0, 0.9868421052631579, 0.9975308641975309]
# Recall: [0.99812734082397, 1.0, 0.9957805907172996, 0.997907949790795, 0.9954233409610984, 0.997872340425532, 0.9936305732484076, 0.9923664122137404, 0.9920634920634921, 0.9829683698296837]
# Training: Precision: [0.9852125693160814, 0.9975728155339806, 0.9957805907172996, 0.9958246346555324, 0.9954233409610984, 0.9957537154989384, 1.0, 1.0, 0.9868421052631579, 0.9975308641975309]
# ...
